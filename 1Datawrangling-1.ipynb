# %%
# Title of the Assignment: Data Wrangling-I
# Perform the following operations using Python on any open source dataset (e.g., data.csv)
# Import all the required Python Libraries.
# 1. Locate open source data from the web (e.g. https://www.kaggle.com).
# 2. Provide a clear description of the data and its source (i.e., URL of the web site).
# 3. Load the Dataset into the pandas data frame.
# 4. Data Preprocessing: check for missing values in the data using pandas insull(), describe()
# function to get some initial statistics. Provide variable descriptions. Types of variables etc.
# Check the dimensions of the data frame.
# 5. Data Formatting and Data Normalization: Summarize the types of variables by checking
# the data types (i.e., character, numeric, integer, factor, and logical) of the variables in the
# data set. If variables are not in the correct data type, apply proper type conversions.
# 6. Turn categorical variables into quantitative variables in Python.

# %%
import pandas as pd   #import required libraries
import numpy as np

# %%
df = pd.read_csv("C:/Users/Manish/Downloads/Iris.csv") #load dataset

# %%
df #print
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head() #print first 5 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull()    #The isnull() method in Pandas is used to detect missing values
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()   #The isnull() method in Pandas is used to detect missing values & sum() method then counts number of True values in each column.
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.notnull() #The pandas.notnull() function is used to detect non-missing values in a DataFrame or Series.Non-missing values get mapped to True, while missing values like None or numpy.NaN get mapped to False.
# Out:
#        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    True           True          True           True          True     True
# 1    True           True          True           True          True     True
# 2    True           True          True           True          True     True
# 3    True           True          True           True          True     True
# 4    True           True          True           True          True     True
# ..    ...            ...           ...            ...           ...      ...
# 145  True           True          True           True          True     True
# 146  True           True          True           True          True     True
# 147  True           True          True           True          True     True
# 148  True           True          True           True          True     True
# 149  True           True          True           True          True     True
#
# [150 rows x 6 columns]

# %%
df.notnull().sum() #sum() method then counts number of True values in each column.
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.describe()
#The describe() method in Pandas is a powerful tool for generating descriptive statistics of a DataFrame or Series. 
#It provides a summary of the central tendency, dispersion, and shape of a dataset's distribution, excluding NaN values. 
#This method is particularly useful for quickly understanding the basic statistical properties of your data.
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.size  # the size of a DataFrame refers to the total number of elements it contains.
# Out:
# 900

# %%
df.ndim  
#the ndim attribute is used to retrieve the number of dimensions, or axes, of a DataFrame or Series object.
#This attribute is particularly useful when you need to confirm the structure of your data
# Out:
# 2

# %%
df.shape
#The shape property in pandas is used to get the dimensions of a DataFrame. 
#It returns a tuple representing the number of rows and columns in the DataFrame
# Out:
# (150, 6)

# %%
df.info() 
#provides a summary of a DataFrame, including number of columns, column labels, data types, memory usage, and number of non-null values in each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df["SepalLengthCm"].astype(int)
#.astype() is used to convert data type of DataFrame or Series to specified type.This is particularly useful in data preprocessing & transformation tasks.
# Out:
# 0      5
# 1      4
# 2      4
# 3      4
# 4      5
#       ..
# 145    6
# 146    6
# 147    6
# 148    6
# 149    5
# Name: SepalLengthCm, Length: 150, dtype: int64

# %%
df = df.dropna()  
#is used to remove missing values (NaN) from a DataFrame. It can be used to drop rows or columns that contain missing values.

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df["SepalLengthCm"].astype(int)
# Out:
# 0      5
# 1      4
# 2      4
# 3      4
# 4      5
#       ..
# 145    6
# 146    6
# 147    6
# 148    6
# 149    5
# Name: SepalLengthCm, Length: 150, dtype: int64

# %%
df["Species"].replace({"Iris-setosa":0,"Iris-versicolor":1,"Iris-virginica":3}, inplace=True)
#This method allows you to replace specific values with new ones, either across the entire DataFrame or within specific columns.
# Out:
# C:\Users\Manish\AppData\Local\Temp\ipykernel_9388\3294641334.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Species"].replace({"Iris-setosa":0,"Iris-versicolor":1,"Iris-virginica":3}, inplace=True)
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        3
# 146  147            6.3           2.5            5.0           1.9        3
# 147  148            6.5           3.0            5.2           2.0        3
# 148  149            6.2           3.4            5.4           2.3        3
# 149  150            5.9           3.0            5.1           1.8        3
#
# [150 rows x 6 columns]
